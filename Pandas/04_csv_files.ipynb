# %%
import pandas as pd

# %%
# Creating a csv file
stu_data = {"Name":["Uday","Yash","Parth","Suryansh","Siddharth"], "Roll_No": [10,23,1,26,15]}

print(stu_data)
print()

data = pd.DataFrame(stu_data)
data_csv = data.to_csv("Test_Data") ## Converted to csv
data_csv = data.to_csv("Test_Data_1", index=False) ## Converted to csv without index showing
data_csv = data.to_csv("Test_Data_2", index=False, header=["stu_name", "stu_enroll"]) ## Converted to csv without index showing and with new headers
# Out:
# {'Name': ['Uday', 'Yash', 'Parth', 'Suryansh', 'Siddharth'], 'Roll_No': [10, 23, 1, 26, 15]}
